# %% [markdown]
# ## Quiz: Define a Dictionary
#
# Define a dictionary named `population` that contains this data:
#
# |  **Keys** | **Values**  |
# |---|---|
# |  Shanghai | 17.8  |
# |  Istanbul | 13.3  |
# |  Karachi |  13.0 |
# |  Mumbai | 12.5  |

# %%
# TODO: replace None with appropriate code
# Define a dictionary, `population`, that provides information
# on the world's largest cities. The key is the name of a city
# (a string), and the associated value is its population in
# millions of people.
#   Key     |   Value
# Shanghai  |   17.8
# Istanbul  |   13.3
# Karachi   |   13.0
# Mumbai    |   12.5
population = {'Shanghai': 17.8,
              'Istanbul': 13.3,
              'Karachi': 13.0,
              'Mumbai': 12.5}

### Notebook grading
population_solution = {"Shanghai": 17.8, 
              "Istanbul": 13.3,
              "Karachi": 13.0,
              "Mumbai": 12.5}

if population == population_solution:
    print("""Nice work!\nYou can see our solution in the next page.""")
elif type(population) != dict:
    print("The data type of `population` should be a dictionary.")
elif len(population) != 4:
    print("Your dictionary should have four key-value pairs in it.")
elif 17800000 in population.values():
    print("Your dictionary values should be floats like `17.8`.")
else:
    print("Double check your code, does it define a dictionary named `population`?")
# Out:
# Nice work!
# You can see our solution in the next page.
